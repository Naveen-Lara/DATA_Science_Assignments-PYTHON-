# %% [markdown]
# **Constructor:**

# %% [markdown]
# **1. What is a constructor in Python? Explain its purpose and usage.**
#
#
# *   Constructors are inbuilt functions used to instantiate an object.
# *   Constructors are used to assign values to the data members of the class when an object is created.
# *   "*__init__*" method is the constructor, called automatically when an object is created
#
# **Types:**
#
#
# 1.   Parameterised 2.   Parameterless Constructor

# %% [markdown]
# **2. Differentiate between a parameterless constructor and a parameterized constructor in Python.**
#
# *   **Parameterless Constructor:**
#         *   Accepts no arguments
#         *   Its definition holds only the reference to the instance being constructed.
#
#
# *   **Parameterised Constructor:**
#         *   Accepts n number of arguments
#         *   The first parameter acts as a reference to the instance being constructed,rest of the parameters are provided by the users

# %%
# @title 3. How do you define a constructor in a Python class? Provide an example.
class example:
  def __init__(self):
    pass

# %% [markdown]
# **4. Explain the `__init__` method in Python and its role in constructors.**
#
#
# *   The "*__init__*" method is a spencial method used to asiign values to the data members of the class when instatiated.
# *   The Role of this method in constructor is to implement any kind of initialization in the class,

# %%
#@title 5. In a class named `Person`, create a constructor that initializes the `name` and `age` attributes. Provide an example of creating an object of this class.
class person:
  def __init__(self,name,age):
    self.name=name
    self.age=age

# %%
naveen=person('Naveen',26)

# %%
#@title 6.How can you call a constructor explicitly in Python? Give an example.
#@markdown A constructor can be called during the instatiation of the object itself.
#@markdown For example:
class cons:
  def __init__(self,param):
    self.param=param
    print(param)

# %%
obj1=cons("tyre")
# Out:
# tyre

# %%
# @title 7. What is the significance of the `self` parameter in Python constructors? Explain with an example
#@markdown The "self" parameter is not a keyword,the first parameter of the method is considered as pointer/ reference.
#@markdown Because in python the methods are **called automatically** when the object is instatiated,but the values passed to the data memebers are not **received automatically**,so the passed first parameter acts as pointer to the object to refer that the value in the variable is belonged to the object.

class dog:
  def __init__(self,name,age):
    self.name=name #instance variable
    self.age=age #instance variable
  def bark(self):
    print(f'The {self.name} says Woof woof!!')

# %%
spark=dog("spark",3)
spark.bark()
# Out:
# The spark says Woof woof!!

# %% [markdown]
# **8. Discuss the concept of default constructors in Python. When are they used?**
#
# *    A default constructor, also known as a no-argument constructor, is a constructor that doesn’t take any parameters. It is automatically called when an object is created without any explicit arguments specified. The default constructor ensures that an object is initialized with default values.

# %%
class def_cons:
  def __init__(self): #default constructor
    self.pi=3.141
  def area_circle(self,r):
    area= (self.pi)*(r**2)
    return area

shape=def_cons() #no parameters required to create a class
shape.area_circle(5)
# Out:
# 78.525

# %%
#@title 9. Create a Python class called `Rectangle` with a constructor that initializes the `width` and `height` attributes. Provide a method to calculate the area of the rectangle.
class rectangle:
  def __init__(self,width,height):
    self.width=width
    self.height=height
  def area_rect(self):
    area=self.width*self.height
    return area

rectangle=rectangle(8,5)

rectangle.area_rect()
# Out:
# 40

# %% [markdown]
# **10. How can you have multiple constructors in a Python class? Explain with an example.**
#
# *   It is not possible to have multiple constructors using different signatures.
# *   It is possible by using *Class method or factory methods*,can be used like constructor itself,parameters are passed during instatiation.

# %%
class params:
  def __init__(self,radius):
    self.radius=radius
    self.pi=3.141
  @classmethod # constructor of different sign using class method
  def from_diameter(cls,diameter):
    radius= diameter/2
    return cls(radius)
  def calc_area(self):
    area= self.pi*(self.radius**2)
    return area

# %%
circle1=params(5)
circle1.calc_area()
# Out:
# 78.525

# %%
circle2=params.from_diameter(10)
circle2.calc_area()
# Out:
# 78.525

# %% [markdown]
# **11. What is method overloading, and how is it related to constructors in Python?**
#
#
#
# *   If the methods in a class has same name with different signature(parameters,return value) is called as *method overloading*.
# *   If a class has constructors in same name with different signatures,it is called *constructor overloading*.

# %% [markdown]
# **12. Explain the use of the super() function in Python constructors. Provide an example.**
#
#
# *   Super function allows to use the variables and methods from parent class to the subclass, also it allows to customise the methods and variables from the parent class.

# %%
class emp:
  def __init__(self,name,age):
    self.name=name
    self.age=age
  def emp_details(self):
    return self.name,self.age

class freelancer(emp):
  def __init__(self,name,age,email):
    super().__init__(name,age)
    self.email=email
  def details(self):
    print(f"Freelancer data:{self.name}, {self.age}, {self.email}")

# %%
guptil=freelancer(25,"guptil","guptil@gmail.com")
guptil.details()
# Out:
# Freelancer data:25, guptil, guptil@gmail.com

# %%
#@title 13. Create a class called `Book` with a constructor that initializes the `title`, `author`, and `published_year` attributes. Provide a method to display book details.
class book:
  def __init__(self,title,author,published_year):
    self.title=title
    self.author=author
    self.published_year=published_year
  def display_details(self):
    print(f"This method displays book details:\nTitle:{self.title}\nAuthor:{self.author}\nPublished year:{self.published_year}")

# %%
sapiens=book("Sapiens.An history of mankind","Yuhal K Nohari",2002)
sapiens.display_details()
# Out:
# This method displays book details:
# Title:Sapiens.An history of mankind
# Author:Yuhal K Nohari
# Published year:2002

# %% [markdown]
# **14. Discuss the differences between constructors and regular methods in Python classes.**
#
# *   Constructors are special methods that are automatically executed during the instance is created.
# *   Regular Methods can be called through objects or classes.

# %% [markdown]
# **15. Explain the role of the `self` parameter in instance variable initialization within a constructor.**
#
# *   *Self* is not a keyword,but when passed as an first argument in a constructor method, it acts as a reference or pointer to the datamembers of the class when it is instantiated.

# %%
#@title 16. How do you prevent a class from having multiple instances by using constructors in Python? Provide an example

# %%
#@title 7. Create a Python class called `Student` with a constructor that takes a list of subjects as a parameter and initializes the `subjects` attribute
class student:
  def __init__(self,subjects):
    self.subjects=subjects
  def display_sub(self):
    return self.subjects

Science_student=student(["maths","cs","physics","chemistry",'language'])
Science_student.display_sub()
# Out:
# ['maths', 'cs', 'physics', 'chemistry', 'language']

# %% [markdown]
# **18. What is the purpose of the `__del__` method in Python classes, and how does it relate to constructors?**
#
# *   The __del__ method in Python classes serves as a destructor, which is called when an object is about to be destroyed or garbage collected.
# *   Complement to __init__: While the __init__ method (the constructor) is used to initialize an object when it is created, the __del__ method is invoked just before the object is destroyed. Together, they manage the lifecycle of an object.

# %%
#@title 19. Explain the use of constructor chaining in Python. Provide a practical example.
#@markdown Constructor chaining refers to the practice of calling constructors from Super class to base class,can be acheived using "super()" method

class vehicle:
  def __init__(self,model,make):
    self.model=model
    self.make=make
class car(vehicle):
  def __init__(self,model,make,num_doors):
    super().__init__(model,make)
    self.num_doors=num_doors
  def car_details(self):
    return self.model,self.make,self.num_doors
toyota=car("toyota","corolla",4)
toyota.car_details()
# Out:
# ('toyota', 'corolla', 4)

# %%
#@title 20. Create a Python class called `Car` with a default constructor that initializes the `make` and `model` attributes. Provide a method to display car information
class car:
  def __init__(self,model,make):
    self.model=model
    self.make=make
  def car_details(self):
    return self.model,self.make

# %%
altroz=car("TATA","Altroz")
altroz.car_details()
# Out:
# ('TATA', 'Altroz')

# %% [markdown]
# **Inheritance**

# %% [markdown]
# **1. What is inheritance in Python? Explain its significance in object-oriented programming**
#
#
# *   Inheritance allows to create a heirarchy of classes from one class derived from other class.
# *   Provides reusability of the code.
# *   It is transitive in nature, which means that if class B inherits from another class A, then all the subclasses of B would automatically inherit from class A.

# %% [markdown]
# **2. Differentiate between single inheritance and multiple inheritance in Python. Provide examples for each**
#
# *Single Inheritance:*
#
# *   When a base class is inherited from a single parent class is called *Single Inheritance*
#
# *Multiple Inheritance:*
#
#
#
# *    When a base class is inherited from multiple parent class is called *Multiple Inheritance*

# %%
#@title *Single inheritance:*

class person:
  def __init__(self,fname,lname):
    self.first_name=fname
    self.second_name=lname
  def details(self):
    print(self.first_name,self.second_name)
class teacher(person):
  pass

# %%
john=teacher("john","Rusty")
john.details()
# Out:
# john Rusty

# %%
#@title *Multiple Inheritance:*
class person:
  def __init__(self,fname,lname):
    self.first_name=fname
    self.second_name=lname
  def details(self):
    print(self.first_name,self.second_name)
class personal_details:
  def __init__(self,dob,age,subject):
    self.dob=dob
    self.age=age
    self.subject=subject
  def get_personal_details(self):
    return self.age,self.dob,self.subject


class teacher(person,personal_details):
  def __init__(self,fname,lname,dob,age,subject):
    person.__init__(self,fname,lname)
    personal_details.__init__(self,dob,age,subject)



venkatesh=teacher("Venkatesh","Bhat",1984,40,"Maths")
venkatesh.details() #inherited from person class
venkatesh.get_personal_details() #Inherited from personal_details class
# Out:
# Venkatesh Bhat
# (40, 1984, 'Maths')

# %%
#@title 3. Create a Python class called `Vehicle` with attributes `color` and `speed`. Then, create a child class called `Car` that inherits from `Vehicle` and adds a `brand` attribute. Provide an example of creating a `Car` object
class vehicle:
  def __init__(self,color,speed):
    self.color=color
    self.speed=speed
class car(vehicle):
  def __init__(self,color,speed,brand):
    super().__init__(color,speed)
    self.brand=brand
  def details(self):
    return self.color,self.speed,self.brand

corolla=car("black",200,"Toyota") #object
corolla.details()
# Out:
# ('black', 200, 'Toyota')

# %%
#@title 4. Explain the concept of method overriding in inheritance. Provide a practical example
#@markdown Method overriding allows to provide specific implemetation of method inherited from its parentclass, which might have same datamembers,return type
class animal:
  def __init__(self):
    self.eat="Carnivore/herbivore"
  def category(self):
    return self.eat

class tiger(animal):
  def __init__(self):
    self.eat="Carnivore"
  def category(self):
    return self.eat

rocky=tiger()
shenbagam=animal()
shenbagam.category(),rocky.category()
# Out:
# ('Carnivore/herbivore', 'Carnivore')

# %%
#@title 5. How can you access the methods and attributes of a parent class from a child class in Python? Give an example.
#@markdown There are two approaches to access the methods and attributes of a parent class to child class ,by using *super()* method or using *classname.methodname*

class animal:
  def __init__(self,species):
    self.species=species

  def sound(self):
    print("some sound")

class dog(animal):
  def __init__(self,name):
    super().__init__("dog") # using super() method
    self.name=name
  def sound(self):
    print("bark")
  def dog_details(self):
    return self.species,self.name

class cat(animal):
  def __init__(self,name):
    animal.__init__(self,"cat") # using direct acess of class
    self.name=name
  def sound(self):
    print("meow")
  def feline_details(self):
    return self.species,self.name

# %%
spark=dog("spark")
spark.dog_details()
# Out:
# ('dog', 'spark')

# %%
Luna=cat("Luna")
Luna.feline_details()
# Out:
# ('cat', 'Luna')

# %%
#@title 6. Discuss the use of the `super()` function in Python inheritance. When and why is it used? Provide an example
# @markdown *super()* method is mainly used in acessing the variables and methods from parent class to child class.It can be used when the methods in child class requires a value from the parent class.

class pwskills:
  def __init__(self,course):
    self.course=course
class ds(pwskills):
  def __init__(self,mentor,course):
    super().__init__(course)
    self.mentor=mentor
  def disp_details(self):
    return self.course,self.mentor

ml=ds("datascience","sudhanshu")
ml.disp_details()
# Out:
# ('sudhanshu', 'datascience')

# %%
#@title 7. Create a Python class called `Animal` with a method `speak()`. Then, create child classes `Dog` and `Cat` that inherit from `Animal` and override the `speak()` method. Provide an example of using these classes
class animal:
  def __init__(self):
    self.sound="some sound"
  def speak(self):
    return self.sound

class dog(animal):
  def __init__(self):
    self.sound="Woof Woof!!"
  def speak(self):
    return self.sound
class cat(animal):
  def __init__(self):
    self.sound="Meow!!"
  def speak(self):
    return self.sound

teddy=dog()
luna=cat()
teddy.speak(),luna.speak()
# Out:
# ('Woof Woof!!', 'Meow!!')

# %% [markdown]
# **8. Explain the role of the `isinstance()` function in Python and how it relates to inheritance.**
#
#
#
#
# *   *isintance()* method is used to check whether the object is instantiated to a particular class or a tuple of classes
# *   In inheritance the method is used to finds the object that a class belongs to.

# %%
#@title 9. What is the purpose of the `issubclass()` function in Python? Provide an example.
#@markdown *issubclass()* method is used to check whether the object is a subclass of a particular class or a tuple of classes.Return **True** if the subclass belongs to the particular class

issubclass(bool,int),issubclass(float,int)
# Out:
# (True, False)

# %% [markdown]
# **10. Discuss the concept of constructor inheritance in Python. How are constructors inherited in child classes?**
#
# *   Constructors are inherited from parent class to baseclass using super() method and the constructors are inherited using direct acess of the parent class

# %%
#@title 11. Create a Python class called `Shape` with a method `area()` that calculates the area of a shape. Then, create child classes `Circle` and `Rectangle` that inherit from `Shape` and implement the `area()` method accordingly. Provide an example.
class shape:
  def area():
    pass
class circle(shape):
  def __init__(self,r):
    self.r=r
    self.pi=3.141
  def area(self):
    area=self.pi*(self.r**2)
    return area
class rectangle(shape):
  def __init__(self,l,b,h):
    self.l=l
    self.h=h
    self.b=b
  def area(self):
    area= self.l*self.h*self.b
    return area

area_circle=circle(5)
rect_area=rectangle(2,5,8)
print(f"AREA OF CIRCLE:{area_circle.area()},AREA OF RECTANGLE: {rect_area.area()}")
# Out:
# AREA OF CIRCLE:78.525,AREA OF RECTANGLE: 80

# %%
#@title 12. Explain the use of abstract base classes (ABCs) in Python and how they relate to inheritance. Provide an example using the `abc` module.
#@markdown *Abstract base classes* are the bluepeint for the child classes,because implemntation of inheritance does not give control over the methods to be used in the child class,but abstraction class ensures that all the methods in the base class are implemented in the subclass.

from abc import ABC,abstractmethod
class baseclass(ABC):
  @abstractmethod
  def test1(self):
    pass
  @abstractmethod
  def test2(self):
    pass
  @abstractmethod
  def test3(self):
    pass
class subclass(baseclass):
  def test1(self):
    print("TEST1")
  def test2(self):
    print("TEST2")
  def test3(self):
    print("Test3")
o2=subclass()
o2.test1()
o2.test3()
# Out:
# TEST1
# Test3

# %% [markdown]
# **13. How can you prevent a child class from modifying certain attributes or methods inherited from a parent
# class in Python?**
#
#
# *   Protected varaible and protected methods helps to prevent a child class from modifying certain attributes or methods inherited from parent class in python.

# %%
#@title 14. Create a Python class called `Employee` with attributes `name` and `salary`. Then, create a child class `Manager` that inherits from `Employee` and adds an attribute `department`. Provide an example.
class employee:
  def __init__(self,name,salary):
    self.name=name
    self.salary=salary

class manager(employee):
  def __init__(self,name,salary,department):
    super().__init__(name,salary)
    self.department=department
  def manager_details(self):
    print(f'MANAGER NAME:{self.name}\nSALARY:{self.salary}\nDEPARTMENT:{self.department}')

yuvaraj_shankar=manager("Yuvaraj_shankar",250,"House keeping")
yuvaraj_shankar.manager_details()
# Out:
# MANAGER NAME:Yuvaraj_shankar
# SALARY:250
# DEPARTMENT:House keeping

# %% [markdown]
# **15. Discuss the concept of method overloading in Python inheritance. How does it differ from method
# overriding**
#
#
#
# *   *Method Overloading;* allows to use multiple method of same name but with difeerent parameters.Method overloading is possible in python.
# *   *Method Overriding* refers to provide specific implementation of certain methods of subclass inherited from base class.

# %% [markdown]
# **16. Explain the purpose of the `__init__()` method in Python inheritance and
# how it is utilized in child classes.**
#
#
#
# *   *`__init__()`* method or constructor fn is a inbuilt special method ,that is called automatically when an instance is created.
# *   This method holds datamembers that can be varied object to object.
#
#
# *   The constructor function can be inherited to the subclasses from base class using *super()* method, where the attributes of the base class can be called to subclasses as well.

# %%
#@title 17. Create a Python class called `Bird` with a method `fly()`. Then, create child classes `Eagle` and `Sparrow` that inherit from `Bird` and implement the `fly()` method differently. Provide an example of using these classes.
class bird:
  def fly(self):
    print("bird flies")
class eagle(bird):
  def __init__(self,species):
    self.species=species
  def fly(self):
    print(f"The {self.species} flies above clouds")
class sparrow(bird):
  def __init__(self,species):
    self.species=species
  def fly(self):
    print(f"The {self.species} flies between trees")

harpick=eagle("eagle")
jack=sparrow("sparrow")
harpick.fly(),jack.fly()
# Out:
# The eagle flies above clouds
# The sparrow flies between trees
# (None, None)

# %% [markdown]
# **18. What is the "diamond problem" in multiple inheritance, and how does Python address it**
#
#
# *   *Diamond Problem* is multiple inheritance it due to the both base classes are inherits methods of super class,and then both thd base classes are inherited to a subclass which forms a diamond shape in Inheritance tree, now if a method from subclass is called  a confict is raised ,which method need to be called first.
# *   This conflict is resolved in python by using *MRO-Method Resolution Order*,which looks for **defined order** in calling the method and attributes.

# %% [markdown]
# **19. Discuss the concept of "is-a" and "has-a" relationships in inheritance, and provide examples of each.**
#
#
# *   *is-a* relationship refers to the subclass inherited from baseclass.for example
#
# ```
# # class bird:
#   def fly(self):
#     print("bird flies")
# class eagle(bird): #is-a relationship in inheritance
#   def __init__(self,species):
#     self.species=species
#   def fly(self):
#     print(f"The {self.species} flies above clouds")
# ```
#
#
# *   *has-a* relationship refers to the presence of a class into another class(composition).
#
#
#
# ```
# # class Engine:
#     def start(self):
#         return "Engine starting"
#
# class Car:
#     def __init__(self):
#         self.engine = Engine()  # Car "has-a" relationship
#
#     def start(self):
#         return self.engine.start()
# ```

# %%
#@title 20. Create a Python class hierarchy for a university system. Start with a base class `Person` and create child classes `Student` and `Professor`, each with their own attributes and methods. Provide an example of using these classes in a university context

class Person:
    def __init__(self, name, age):
        self.name = name
        self.age = age

class Student(Person):
    def __init__(self, name, age, std_id, dpt):
        super().__init__(name, age)
        self.std_id = std_id
        self.dpt = dpt

    def display_student_details(self):
        print(f"STUDENT NAME: {self.name}\nSTUDENT ID: {self.std_id}\nDEPARTMENT: {self.dpt}")

class Professor(Person):
    def __init__(self, name, age, prof_id, dpt, specialization):
        super().__init__(name, age)
        self.prof_id = prof_id
        self.dpt = dpt
        self.specialization = specialization

    def display_professor_details(self):
        print(f"PROFESSOR NAME: {self.name}\nPROFESSOR ID: {self.prof_id}\nDEPARTMENT: {self.dpt}\nSPECIALIZATION: {self.specialization}")

# Creating a Student object
student1 = Student(name="Alice", age=20, std_id="S12345", dpt="Computer Science")
student1.display_student_details()

# Creating a Professor object
professor1 = Professor(name="Dr. Smith", age=45, prof_id="P67890", dpt="Mathematics", specialization="Algebra")
professor1.display_professor_details()
# Out:
# STUDENT NAME: Alice
# STUDENT ID: S12345
# DEPARTMENT: Computer Science
# PROFESSOR NAME: Dr. Smith
# PROFESSOR ID: P67890
# DEPARTMENT: Mathematics
# SPECIALIZATION: Algebra

# %% [markdown]
# **Encapsulation:**

# %% [markdown]
# **1. Explain the concept of encapsulation in Python. What is its role in object-oriented programming?**
#
# *   Encapsulation refers to wrapping of variables and methods into a single unit.It cannot be accessed using objects.
# *   It helps to avoid accidental changes of the attributes through objects.

# %% [markdown]
# **2. Describe the key principles of encapsulation, including access control and data hiding**
#
#
# *   *Access Control*: helps the when and where the attributes and methods can be acheived.
#
#               *   Public Variables-can be accessed outside objects as well as classes.
#               *   Private Variables- -Members are accessible within the class and its subclasses.
#               *   Protected Variables- Members are accessible only within the class.
#
#
#
# *   *Data Hiding:* involves in resticting the acess of the certain components of the object to protect its initernal state.

# %%
#@title 3. How can you achieve encapsulation in Python classes? Provide an example.
class encapsulated:
  def __init__(self):
    self._a="Encapsulated Variable" #private variable caanot be accesible by the object.
  def dd(self):
    return self._a

example=encapsulated()
example.dd()
# Out:
# 'Encapsulated Variable'

# %% [markdown]
# **4. Discuss the difference between public, private, and protected access modifiers in Python**
#
#
# *   Public variable- can be accessed inside class or by object.
# *   Private Variable- can be accessed only within the classes and its subclasses.Cannot aceesed by the object unless the name of the variable or method is known.
# *   Protected Variable-Can be accessed only within the class.

# %%
#@title 5. Create a Python class called `Person` with a private attribute `__name`. Provide methods to get and set the name attribute.
class person:
  def __init__(self,name):
    self.__name=name
  def get(self):
    return self.__name
  def set(self,new_name):
    self.__name= new_name
    return self.__name

sudh=person('Sudhanshu kumar')
sudh.get(), sudh.set("Krish Naik")
# Out:
# ('Sudhanshu kumar', 'Krish Naik')

# %%
#@title 6. Explain the purpose of getter and setter methods in encapsulation. Provide examples
#@markdown Getter and Setter methods are mainly used in accessing the private datamembers of class,It can be acheived through normal functions as well as through Decorators, using *Property dectorator*

class person:
  def __init__(self,name):
    self._name=name
  @property
  def name(self):
    return self._name
  @name.setter
  def name(self,new_name):
    self._name= new_name
    return self._name

sudh=person('Sudhanshu kumar')
sudh.name # prints sudhanshu kumar, used getter method
sudh.name="Krish Naik"
sudh.name # prints Krish Naik, used setter method
# Out:
# 'Krish Naik'

# %% [markdown]
# **7. What is name mangling in Python, and how does it affect encapsulation**
#
#
# *   Name Mangling in python is used to prevent name clashes bw classes,especially during inheritance.
# *   Name mangling ensures that the method or variable is not accidentally overridden.

# %%
#@title 8. Create a Python class called `BankAccount` with private attributes for the account balance (`__balance`) and account number (`__account_number`). Provide methods for depositing and withdrawing money.
class bankaccount:
  def __init__(self,account_number):
    self.__balance=0
    self.__account_number=account_number
  def deposit_money(self,account_number,amount):
    if self._bankaccount__account_number==account_number:
      self._bankaccount__balance=self._bankaccount__balance+amount
      print(f"Amount depsosited successfully, account balance {self._bankaccount__balance}")
    else:
      print("Invalid account number")
  def Withdraw_money(self,account_number,wd_amount):
    if self._bankaccount__account_number==account_number and self._bankaccount__balance >= wd_amount  :
      self._bankaccount__balance=self._bankaccount__balance-wd_amount
      print(f"Withdrawl {wd_amount} successfull")
    else:
      print("Invalid account number / Insufficient Balance")

naveen=bankaccount("KODACK786888")
naveen.deposit_money("KODACK786888",25000)
naveen.Withdraw_money("KODACK786888",5000)
# Out:
# Amount depsosited successfully, account balance 25000
# Withdrawl 5000 successfull

# %% [markdown]
# **9. Discuss the advantages of encapsulation in terms of code maintainability and security.**
#
# 1. Code Maintainability
# Modularity: Encapsulation promotes modular design, allowing developers to isolate changes. If a class implementation needs to be modified, it can be done without affecting other parts of the codebase.
# 2. Security
# Controlled Access: By using access modifiers (e.g., private, protected), developers can control how and when data is accessed or modified, enforcing rules and maintaining the integrity of the data.

# %%
#@title 10. How can you access private attributes in Python? Provide an example demonstrating the use of name mangling
#@markdown Private variables can be accessed using *__variablename*.called name mangling
class MyClass:
    def __init__(self):
        self.__private_var = "I am private"

    def get_private_var(self):
        return self.__private_var  # Accessible within the class

obj = MyClass()
# print(obj.__private_var)  # This would raise an AttributeError
print(obj.get_private_var())  # Outputs: I am private
# Out:
# I am private

# %%
#@title 11. Create a Python class hierarchy for a school system, including classes for students, teachers, and courses, and implement encapsulation principles to protect sensitive information.
class person:
  def __init__(self,name,age):
    self._name=name
    self._age=age
  @property
  def name(self):
    return self._name
  def age(self):
    return self._age
class Student(person):
  def __init__(self,name,age,student_id):
    super().__init__(name,age)
    self.__student_id=student_id
  def get_info(self):
    print(f"Name:{self._name}\nAge:{self._age}\nStudent_id:{self.__student_id}")
class Teacher(person):
  def __init__(self,name,age,emp_id):
    super().__init__(name,age)
    self.__emp_id=emp_id
  def get_info(self):
    print(f"Name:{self._name}\nAge:{self._age}\nStudent_id:{self.__emp_id}")
class course:
  def __init__(self,course_name,code):
    self.course_name=course_name
    self.code=code
    self._student=[]
  def enrollment(self,student):
    if isinstance(student,Student):
      self._student.append(student)
    else:
      print("Only students can enroll")
  def studentsenrolled(self):
    return [student.get_info() for student in self._student]
  def teacher_info(self,teacher_name):
    if isinstance(teacher_name,Teacher):
      return teacher_name.get_info()
    else:
      print(f"{self.teacher_name} is not a part of the course")

Niran=Student("Nirandharan",25,"pws005")
sanju=Student("Sanju Sushanth",25,"pws006")
Sudhanshu=Teacher("Sudhanshu Kumar",40,"Ineuron005")

datascience=course("datascience","pwscourse001")
datascience.enrollment(Niran)
datascience.enrollment(sanju)
datascience.studentsenrolled()
print("____________________________")
datascience.teacher_info(Sudhanshu)
# Out:
# Name:Nirandharan
# Age:25
# Student_id:pws005
# Name:Sanju Sushanth
# Age:25
# Student_id:pws006
# ____________________________
# Name:Sudhanshu Kumar
# Age:40
# Student_id:Ineuron005

# %% [markdown]
# **12. Explain the concept of property decorators in Python and how they relate to encapsulation**
#
# *   *Property* decorators are used in defining the properties without calling the inbuilt property function.
# *   *getter* and *setter* properties are mainly used in retriving the protected and priate variables.

# %%
#@title 13. What is data hiding, and why is it important in encapsulation? Provide examples.
#@markdown Data hiding is a principle of encapsulation in object-oriented programming that restricts access to certain components of an object. It prevents external entities from directly accessing and modifying the internal state of an object. Instead, access is provided through well-defined methods (getters and setters).

class BankAccount:
    def __init__(self, account_number, balance=0):
        self.__account_number = account_number  # Private attribute
        self.__balance = balance  # Private attribute

    def deposit(self, amount):
        if amount > 0:
            self.__balance += amount
            print(f"Deposited: {amount}. New balance: {self.__balance}")
        else:
            print("Deposit amount must be positive.")

    def withdraw(self, amount):
        if 0 < amount <= self.__balance:
            self.__balance -= amount
            print(f"Withdrawn: {amount}. New balance: {self.__balance}")
        else:
            print("Invalid withdrawal amount.")

    def get_balance(self):
        return self.__balance

# Example usage
account = BankAccount("123456789")
account.deposit(100)
account.withdraw(50)
print(f"Final balance: {account.get_balance()}")
# Out:
# Deposited: 100. New balance: 100
# Withdrawn: 50. New balance: 50
# Final balance: 50

# %%
print(account.__balance)  # This will raise an AttributeError
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-52-6397c04bf598> in <cell line: 1>()
# ----> 1 print(account.__balance)  # This will raise an AttributeError
#       2
#
# AttributeError: 'BankAccount' object has no attribute '__balance'

# %%
#@title 14. Create a Python class called `Employee` with private attributes for salary (`__salary`) and employee ID (`__employee_id`). Provide a method to calculate yearly bonuses
class employee:
  def __init__(self,employee_id,salary):
    self.__employee_id=employee_id
    self.__salary=salary
  def emp_details(self):
    return self.__employee_id,self.__salary

  def calc_bonus(self):
    bonus=(self.__salary*0.9)
    return "bonus: "+str(bonus)
yuv=employee("svm1998",250)
yuv.emp_details(),yuv.calc_bonus()
# Out:
# (('svm1998', 250), 'bonus: 225.0')

# %% [markdown]
# **15. Discuss the use of accessors and mutators in encapsulation. How do they help maintain control over
# attribute access**
#
#
#
# *   *Accessors* are also knowns as getters ,which are useful in retriving the protected variables whithout directly accesing it.It prevents the uncontrolled or unintended access of the internal state of the object.
# *   *Mutators* are also known as getters, enables the external code to modify the variables,but with control.

# %% [markdown]
# **16. What are the potential drawbacks or disadvantages of using encapsulation in Python**
#
#
# *   Increased Complexity: Can complicate code with additional methods (getters/setters).
#
# *   Performance Overhead: Slightly slower due to method calls compared to direct access.
# *   Reduced Flexibility: May lead to tight coupling between classes.
#
#
# *   Over-Encapsulation: Excessive use can bloat code unnecessarily.
#
#
# *   ebugging Challenges: Indirect access can make tracing bugs harder.

# %%
#@title 17. Create a Python class for a library system that encapsulates book information, including titles, authors, and availability status
class library:
  def __init__(self,title,author,availability):
    self.__title=title
    self.__author=author
    self.__availability=availability
  @property
  def book_info(self):
    return self.__title,self.__author,self.__availability

  @book_info.setter
  def book_info(self,info):
    title, author, availability = info
    self.__title = title
    self.__author = author
    self.__availability = availability
    print({self.__title},{self.__author},{self.__availability})

mtp=library("Power of your subconcious mind","joseph Murphy","Yes")
mtp.book_info #calling getter fn
# Out:
# ('Power of your subconcious mind', 'joseph Murphy', 'Yes')

# %%
mtp.book_info=("The Alchemist","Paulo chohelo","yes") #calling setter fn

# %% [markdown]
# **18. Explain how encapsulation enhances code reusability and modularity in Python programs**
#
#
# * Modularity: Groups related data and functions, making code easier to manage.
#
# * Controlled Interfaces: Allows internal changes without affecting external code, promoting flexibility.
#
#
# * Reduced Side Effects: Limits direct access to state, preventing unintended interactions.
#
# * Clear APIs: Defines how to use components, encouraging reuse instead of duplication.

# %% [markdown]
# **19. Describe the concept of information hiding in encapsulation. Why is it essential in software development**
#
# *   Data Protection: Prevents unauthorized access and modification of sensitive data.
#
# *   Reduced Complexity: Simplifies the interface by exposing only necessary details, making it easier to use.
# *   Reduced Complexity: Simplifies the interface by exposing only necessary details, making it easier to use.
#
#
# *   Improved Security: Limits the potential for misuse or errors by hiding implementation details.

# %%
#@title 20. Create a Python class called `Customer` with private attributes for customer details like name, address, and contact information. Implement encapsulation to ensure data integrity and security
class customer:
  def __init__(self,name,address,contact_info):
    self.__name=name
    self.__address=address
    self.__contact_info=contact_info
  @property
  def get_name(self):
    return self.__name
  @get_name.setter
  def get_name(self,new_name):
    self.__name=new_name
    return self.__name
  @property
  def get_address(self):
    return self.__address
  @get_address.setter
  def get_address(self,new_address):
    self.__address=new_address
    return self.__address

  @property
  def get_contact_info(self):
    return self.__contact_info
  @get_contact_info.setter
  def get_contact_info(self,new_contact_info):
    self.__contact_info=new_contact_info
    return self.__contact_info

# %%
Muthu=customer("Muthu manikam","27/1,dubai","78688")

# %%
Muthu.get_name,Muthu.get_address,Muthu.get_contact_info
# Out:
# ('Muthu manikam', '27/1,dubai', '78688')

# %%
Muthu.get_name="MANIC BASHA"
Muthu.get_address="27/1,Mumbai"
Muthu.get_contact_info="254875"

# %%
Muthu.get_name,Muthu.get_address,Muthu.get_contact_info
# Out:
# ('MANIC BASHA', '27/1,Mumbai', '254875')

# %% [markdown]
# **Polymorphism:**

# %% [markdown]
# **1. What is polymorphism in Python? Explain how it is related to object-oriented programming.**
#
#
# *   Poly+morphs=many forms,polymorphism means many forms.
# *   A same function can be used for different types but with different signatures.

# %% [markdown]
# **2. Describe the difference between compile-time polymorphism and runtime polymorphism in Python**
#
#
#
# *   *Compile Time polymorphism:* Methods with same name but with different signatures,can be acheived using method overloading.(Not possible in python)
# *   *Run Time Polymorphism* method defined in superclasses can be redefined in subclasses also,can be achieved using METHOD Overriding.

# %%
#@title 3. Create a Python class hierarchy for shapes (e.g., circle, square, triangle) and demonstrate polymorphism  through a common method, such as `calculate_area()`
class Shape:
  def calulate_area(self):
    pass
class Circle(Shape):
  def __init__(self,radius):
    self.radius=radius
    self.pi=3.141

  def calculate_area(self):
    area=self.pi*(self.radius**2)
    return area
class Square(Shape):
  def __init__(self,a):
    self.a=a
  def calculate_area(self):
    area=4*self.a
    return area
class Triangle(Shape):
  def __init__(self,b,h):
    self.b=b
    self.h=h
  def calculate_area(self):
    area= 0.5*self.b*self.h
    return area

c1=Circle(5)
s1=Square(25)
t1=Triangle(2,6)
shapes=[c1,s1,t1]
for shape in shapes:
  print(f"The area of the {shape.__class__.__name__} is: {shape.calculate_area()}")
# Out:
# The area of the Circle is: 78.525
# The area of the Square is: 100
# The area of the Triangle is: 6.0

# %%
#@title 4. Explain the concept of method overriding in polymorphism. Provide an example.
#@markdown Method overriding allows to provide specific implemetation of method inherited from its parentclass, which might have same datamembers,return type
class animal:
  def __init__(self):
    self.eat="Carnivore/herbivore"
  def category(self):
    return self.eat

class tiger(animal):
  def __init__(self):
    self.eat="Carnivore"
  def category(self):
    return self.eat

rocky=tiger()
shenbagam=animal()
shenbagam.category(),rocky.category()
# Out:
# ('Carnivore/herbivore', 'Carnivore')

# %%
#@title 5. How is polymorphism different from method overloading in Python? Provide examples for both
#@markdown *Polymorphism* allows methods to do different things based on the object’s class. It enables a single interface to represent different underlying forms (data types).
class Dog:
    def speak(self):
        return "Woof!"

class Cat:
    def speak(self):
        return "Meow!"

def animal_sound(animal):
    print(animal.speak())

dog = Dog()
cat = Cat()

animal_sound(dog)  # Outputs: Woof!
animal_sound(cat)  # Outputs: Meow!

#@markdown *Method overloading* allows multiple methods with the same name to exist in the same scope, distinguished by different parameters.
class Example:
    def greet(self, name=None):
        if name is not None:
            return f"Hello, {name}!"
        else:
            return "Hello!"

ex = Example()
print(ex.greet())          # Outputs: Hello!
print(ex.greet("Alice"))  # Outputs: Hello, Alice!
# Out:
# Woof!
# Meow!
# Hello!
# Hello, Alice!

# %%
#@title 6. Create a Python class called `Animal` with a method `speak()`. Then, create child classes like `Dog`, `Cat`, and `Bird`, each with their own `speak()` method. Demonstrate polymorphism by calling the `speak()` method on objects of different subclasses.
class Animal:
  def speak(self):
    pass
class Dog(Animal):
  def __init__(self,name):
    self.name=name
  def speak(self):
    print(f"{self.name} sounds WOOF WOOF!!")
class Cat(Animal):
  def __init__(self,name):
    self.name=name
  def speak(self):
    print(f"{self.name} sounds Meow!!")
class Bird(Animal):
  def __init__(self,name):
    self.name=name
  def speak(self):
    print(f"{self.name} sounds Creech Creech!!")

dog,cat,bird=Dog("Spark"),Cat("Luna"),Bird("Lilly")

animals=[dog,cat,bird]
print([animal.speak() for animal in animals])
# Out:
# Spark sounds WOOF WOOF!!
# Luna sounds Meow!!
# Lilly sounds Creech Creech!!
# [None, None, None]

# %%
#@title 7. Discuss the use of abstract methods and classes in achieving polymorphism in Python. Provide an example using the `abc` module
# @markdown *Abstract methods* enforces the subclasses to implement specific methods that are from the baseclass,it is very useful so that the important methods are implemented without fail.
from abc import ABC,abstractmethod
class Animal(ABC):
  @abstractmethod
  def speak(self):
    pass
class Dog(Animal):
  def __init__(self,name):
    self.name=name
  def speak(self):
    print(f"{self.name} sounds WOOF WOOF!!")
class Cat(Animal):
  def __init__(self,name):
    self.name=name
  def speak(self):
    print(f"{self.name} sounds Meow!!")
class Bird(Animal):
  def __init__(self,name):
    self.name=name
  def speak(self):
    print(f"{self.name} sounds Creech Creech!!")

dog,cat,bird=Dog("Spark"),Cat("Luna"),Bird("Lilly")

animals=[dog,cat,bird]
print([animal.speak() for animal in animals])
# Out:
# Spark sounds WOOF WOOF!!
# Luna sounds Meow!!
# Lilly sounds Creech Creech!!
# [None, None, None]

# %%
#@title 8. Create a Python class hierarchy for a vehicle system (e.g., car, bicycle, boat) and implement a polymorphic `start()` method that prints a message specific to each vehicle type.
class Vehicle:
  def __init__(self,model,make):
    self.model=model
    self.make=make
  def start(self):
    raise NotImplementedError("The class is a Baseclass,implement through subclasses")
class Car(Vehicle):
  def __init__(self,model,make):
    super().__init__(model,make)
  def start(self):
    print(f"The car {self.model} Uses RK id to start the ignition")
class Bicycle(Vehicle):
  def __init__(self,model,make):
    super().__init__(model,make)
  def start(self):
    print(f"The Bicycle {self.model} is ready to Ride")

class Boat(Vehicle):
  def __init__(self,model,make):
    super().__init__(model,make)
  def start(self):
    print(f"The Boat {self.model} Roars to life ")

Flash,Hercules,Aquaman=Car("Camry","Toyota"),Bicycle("Hercules","Mtb"),Boat("Hinata","Honda")
objects=[Flash,Hercules,Aquaman]
for i in objects:
  i.start()
# Out:
# The car Camry Uses RK id to start the ignition
# The Bicycle Hercules is ready to Ride
# The Boat Hinata Roars to life

# %% [markdown]
# **9. Explain the significance of the `isinstance()` and `issubclass()` functions in Python polymorphism**
#
#
#
# *   *isinstance()* method is used to identify whether the object created belongs to the particular class, which helps tracking the object.
# *   *issubclass()* method refers to check the subclasses belongs to the specific baseclass which is helpful in implementing methods from the specific subclasses.

# %%
#@title 10. What is the role of the `@abstractmethod` decorator in achieving polymorphism in Python? Provide an example
# @markdown *Abstract methods* enforces the subclasses to implement specific methods that are from the baseclass,it is very useful so that the important methods are implemented without fail.
from abc import ABC,abstractmethod
class Animal(ABC):
  @abstractmethod
  def speak(self):
    pass
class Dog(Animal):
  def __init__(self,name):
    self.name=name
  def speak(self):
    print(f"{self.name} sounds WOOF WOOF!!")
class Cat(Animal):
  def __init__(self,name):
    self.name=name
  def speak(self):
    print(f"{self.name} sounds Meow!!")
class Bird(Animal):
  def __init__(self,name):
    self.name=name
  def speak(self):
    print(f"{self.name} sounds Creech Creech!!")

dog,cat,bird=Dog("Spark"),Cat("Luna"),Bird("Lilly")

animals=[dog,cat,bird]
print([animal.speak() for animal in animals])
# Out:
# Spark sounds WOOF WOOF!!
# Luna sounds Meow!!
# Lilly sounds Creech Creech!!
# [None, None, None]

# %%
#@title 11. Create a Python class called `Shape` with a polymorphic method `area()` that calculates the area of different shapes (e.g., circle, rectangle, triangle).
class Shape:
  def area(self):
    pass
class Circle(Shape):
  def __init__(self,radius):
    self.pi=3.141
    self.radius=radius
  def area(self):
    area = self.pi*self.radius*self.radius
    return area
class Rectangle(Shape):
  def __init__(self,length,height):
    self.length=length
    self.height=height
  def area(self):
    area = 0.5*self.length*self.height
    return area
class Square(Shape):
  def __init__(self,length):
    self.length=length
  def area(self):
    area = 4*self.length
    return area
c1=Circle(8)
r1=Rectangle(2,5)
s1=Square(54)
shapes =[c1,r1,s1]

for shape in shapes:
  print(f"Area of {shape.__class__.__name__} is {shape.area()}")
# Out:
# Area of Circle is 201.024
# Area of Rectangle is 5.0
# Area of Square is 216

# %% [markdown]
# **12. Discuss the benefits of polymorphism in terms of code reusability and flexibility in Python programs**
#
#
#
# *   Common Interface: Polymorphism allows functions to use objects of different classes that share a common interface. This means you can write generic functions that work with any class that implements the required methods.
# *   Reduced Code Duplication: By using polymorphic behavior, you can avoid rewriting similar code for different classes.

# %% [markdown]
# **13. Explain the use of the `super()` function in Python polymorphism. How does it help call methods of parent
# classes**
#
#
# *   *Super()* method refers to the access of functions in baseclass to subclasses,without explicitly naming the baseclass.
# *   It enables you to create flexible class hierarchies that can evolve over time without requiring significant changes to method calls.

# %%
#@title 14. Create a Python class hierarchy for a banking system with various account types (e.g., savings, checking, credit card) and demonstrate polymorphism by implementing a common `withdraw()` method.
class BankAccount:
    def __init__(self, name, acc_num):
        self.name = name
        self.acc_num = acc_num
        self.balance = 0

    def withdraw(self, amount):
        if amount <= self.balance:
            self.balance -= amount
            return self.balance
        else:
            print("Insufficient Funds")


class Savings(BankAccount):
    def __init__(self, name, acc_num):
        super().__init__(name, acc_num)
        self.acc_type = "Savings Account"
        self.withdrawal_limit = 0
        self.max_withdrawals = 4  # Limit on withdrawals

    def withdraw(self, amount):
        if self.withdrawal_limit < self.max_withdrawals and amount <= self.balance:
            self.balance -= amount
            self.withdrawal_limit += 1
            return self.balance
        else:
            print("Insufficient Funds or Reached Withdrawal Limit")


class Current(BankAccount):
    def __init__(self, name, acc_num):
        super().__init__(name, acc_num)
        self.acc_type = "Current Account"

    def withdraw(self, amount):
        return super().withdraw(amount)  # Call the parent class method


class CreditCard(BankAccount):
    def __init__(self, name, acc_num):
        super().__init__(name, acc_num)
        self.acc_type = "Credit Card Account"
        self.credit_limit = 1000  # Example credit limit

    def withdraw(self, amount):
        if amount <= (self.balance + self.credit_limit):  # Allow withdrawal up to credit limit
            self.balance -= amount
            return self.balance
        else:
            print("Insufficient Funds, including credit limit")


# Example usage
savings_account = Savings("Alice", "SAV123")
savings_account.balance = 500  # Setting balance for demonstration
print(savings_account.withdraw(100))  # Should print 400
print(savings_account.withdraw(100))  # Should print 300
print(savings_account.withdraw(100))  # Should print 200
print(savings_account.withdraw(100))  # Should print 100
print(savings_account.withdraw(100))  # Should print "Reached Withdrawal Limit"

current_account = Current("Bob", "CUR456")
current_account.balance = 1000
print(current_account.withdraw(200))  # Should print 800

credit_card_account = CreditCard("Charlie", "CRED789")
credit_card_account.balance = 500
print(credit_card_account.withdraw(1200))  # Should print -700 (balance going into credit)
# Out:
# 400
# 300
# 200
# 100
# Insufficient Funds or Reached Withdrawal Limit
# None
# 800
# -700

# %%
#@title 15. Describe the concept of operator overloading in Python and how it relates to polymorphism. Provide examples using operators like `+` and `*`

class Vector:
  def __init__(self,x,y):
    self.x=x
    self.y=y
  def __add__(self,other):
    return Vector(self.x+other.x,self.y+other.y)
  def __mul__(self,other):
    return Vector(self.x*other.x,self.y*other.y)
  def __repr__(self):
    return  f"Vector({self.x}, {self.y})"

# Example usage
v1 = Vector(2, 3)
v2 = Vector(4, 5)

# Using overloaded +
v3 = v1 + v2  # Vector addition
print(v3)

# Using overloaded *
v4 = v1 * v2  # Scalar multiplication
print(v4)
# Out:
# Vector(6, 8)
# Vector(8, 15)

# %% [markdown]
# **16. What is dynamic polymorphism, and how is it achieved in Python?**
#
# *   Dynamic polymorphism refers to the ability of different objects to respond to the same method call in a way that is determined at runtime.
# *   Can be Acheived through *Method Overriding and Duck typing*

# %%
#@title 17. Create a Python class hierarchy for employees in a company (e.g., manager, developer, designer) and implement polymorphism through a common `calculate_salary()` method.
class company:
  def __init__(self,name,age,basic,allowance):
    self.name=name
    self.age=age
    self.basic=basic
    self.allowance=allowance
  def calculate_salary(self):
    salary= self.basic* (self.allowance/100)
    print(f"the salary of the {self.__class__.__name__} is {salary}")
class manager(company):
  def __init__(self,name,age,basic,allowance):
    super().__init__(name,age,basic,allowance)

  def calculate_salary(self):
    return super().calculate_salary()
class designer(company):
  def __init__(self,name,age,basic,allowance):
    super().__init__(name,age,basic,allowance)

  def calculate_salary(self):
    return super().calculate_salary()
class developer(company):
  def __init__(self,name,age,basic,allowance):
    super().__init__(name,age,basic,allowance)

  def calculate_salary(self):
    return super().calculate_salary()
sachin=manager("sachin",55,8000,25)
mankar=designer("Mankar singh",30,80000,50)
karthi=developer("Karthi PK",25,100000,200)
employees=[sachin,karthi,mankar]
for employee in employees:
  employee.calculate_salary()
# Out:
# the salary of the manager is 2000.0
# the salary of the developer is 200000.0
# the salary of the designer is 40000.0

# %% [markdown]
# **18. Discuss the concept of function pointers and how they can be used to achieve polymorphism in Python.**
#
#
# *   First-Class Functions: In Python, functions are first-class citizens. This means you can assign functions to variables, pass them as arguments to other functions, and return them from functions.
#
#
# *   Higher-Order Functions: A function that takes another function as an argument or returns a function is called a higher-order function. This is where polymorphism can be implemented, allowing different functions to be used interchangeably.

# %%
#@title 19. Create a Python class for a library system, implementing abstraction by defining common methods (e.g., `add_book()`, `borrow_book()`) in an abstract base class.
from abc import ABC,abstractmethod
class Library(ABC):
  books=[]
  def __init__(self,book_title,author):
    self.book_title=book_title
    self.author=author
  @abstractmethod
  def add_book(self):
    if self.book_title not in self.books:
      self.books.append(self.book_title)
      print(f"The book {self.book_title} added successfully\nAvailable Books in {self.__class__.__name__}:{self.books}")
    else:
      print(f"{self.book_title} is already in the {self.__class__.__name__} section\nAvailable Books in {self.__class__.__name__}:{self.books}")
  @abstractmethod
  def borrow_book(self, book_to_borrow):
        if book_to_borrow in self.books:
            self.books.remove(book_to_borrow)
            print(f"The book '{book_to_borrow}' borrowed successfully.\nAvailable Books in {self.__class__.__name__}: {self.books}")
        else:
            print(f"'{book_to_borrow}' is not available in the {self.__class__.__name__} section.\nAvailable Books in {self.__class__.__name__}: {self.books}")
class Science_Section(Library):
  books=[]
  def __init__(self,book_title,author):
    super().__init__(book_title,author)
  def add_book(self):
    super().add_book()
  def borrow_book(self,book_to_borrow):
    super().borrow_book(book_to_borrow)
class Literature_Section(Library):
  def __init__(self,book_title,author):
    super().__init__(book_title,author)
  def add_book(self):
    super().add_book()
  def borrow_book(self,book_to_borrow):
    super().borrow_book(book_to_borrow)


book1=Science_Section('FOCP',"Ankit Bansal")
book2=Literature_Section("Art of War","Sun Tzu")
book3=Science_Section('FOCP-II',"Ankit Bansal")
book4=Literature_Section("All about love","William Shakeshere")
books=[book1,book2,book3,book4]
for book in books:
  book.add_book()
print("------------------------------------")
book3.borrow_book("FOCP-II")
# Out:
# The book FOCP added successfully
# Available Books in Science_Section:['FOCP']
# The book Art of War added successfully
# Available Books in Literature_Section:['Art of War']
# The book FOCP-II added successfully
# Available Books in Science_Section:['FOCP', 'FOCP-II']
# The book All about love added successfully
# Available Books in Literature_Section:['Art of War', 'All about love']
# ------------------------------------
# The book 'FOCP-II' borrowed successfully.
# Available Books in Science_Section: ['FOCP']

# %% [markdown]
# **20. Describe the concept of method abstraction in Python and how it relates to polymorphism.**
#
#
# *   Method abstraction hides implementation details while exposing a method interface through abstract base classes (ABCs).
# *   Different classes can be treated as instances of a common superclass, allowing interchangeable use of objects.Method abstraction supports polymorphism by ensuring a unified interface for diverse implementations

# %% [markdown]
# **Abstraction:**

# %% [markdown]
# **1. What is abstraction in Python, and how does it relate to object-oriented programming?**
#
#
# *   Abstraction refers to hiding implemetation details and only showing functionality to the user.
# *   Classes that has *Abstract Methods* are called as *Abstract Classes* inherited to the subclasses, where abs methods are overriding in the subclasses.

# %% [markdown]
# **2. Describe the benefits of abstraction in terms of code organization and complexity reduction.**
#
# *   Abstraction often involves defining clear interfaces that specify how different components interact, promoting a cleaner separation of concerns.
# *   By using abstraction, developers can avoid code duplication, which simplifies maintenance as updates need to be made in fewer places.

# %%
#@title 3. Create a Python class called `Shape` with an abstract method `calculate_area()`. Then, create child classes (e.g., `Circle`, `Rectangle`) that implement the `calculate_area()` method. Provide an example of using these classes.
from abc import ABC,abstractmethod
class Shape(ABC):
  @abstractmethod
  def calculate_area(self):
    pass

class Circle(Shape):
  def __init__(self,radius):
    self.radius=radius
    self.pi=3.141

  def calculate_area(self):
    area=self.pi*(self.radius**2)
    return area
class Square(Shape):
  def __init__(self,a):
    self.a=a
  def calculate_area(self):
    area=4*self.a
    return area
class Triangle(Shape):
  def __init__(self,b,h):
    self.b=b
    self.h=h
  def calculate_area(self):
    area= 0.5*self.b*self.h
    return area

c1=Circle(5)
s1=Square(25)
t1=Triangle(2,6)
shapes=[c1,s1,t1]
for shape in shapes:
  print(f"The area of the {shape.__class__.__name__} is: {shape.calculate_area()}")
# Out:
# The area of the Circle is: 78.525
# The area of the Square is: 100
# The area of the Triangle is: 6.0

# %% [markdown]
# **4. Explain the concept of abstract classes in Python and how they are defined using the `abc` module. Provide
# an example.**
#
#
#
# *   An abstract class in Python serves as a blueprint for other classes. It cannot be instantiated on its own and is meant to define a common interface for subclasses. Abstract classes can contain abstract methods (which must be implemented by subclasses) and concrete methods (which can be used as-is).
# *   Abstract classes created by inheriting the ABC(abstract base class) by importing abc(abstract base classes) module,abstract methods are created by using *@abstractmethods* decorator.
#
#
#
#
# > For Example
#
#
# ```
# from abc import ABC,abstractmethod
# class Shape(ABC):
#   @abstractmethod
#   def calculate_area(self):
#     pass
# ```

# %% [markdown]
# **5. How do abstract classes differ from regular classes in Python? Discuss their use cases**
# ![image.png](data:image/png;base64,...)

# %%
#@title 6. Create a Python class for a bank account and demonstrate abstraction by hiding the account balance and providing methods to deposit and withdraw funds.
from abc import ABC,abstractmethod
class bank(ABC):
  def __init__(self,name,acc_num,pin):
    self.name=name
    self.acc_num=acc_num
    self.pin=pin
    self.__balance=0
  @abstractmethod
  def deposit_amt(self):
    pass
  @abstractmethod
  def withdraw_amt(self):
    pass
class savings_acc(bank):
  def __init__(self,name,acc_num,pin):
    super().__init__(name,acc_num,pin)
  def deposit_amt(self,deposit_amt):
    self._bank__balance += deposit_amt
    print(f"{deposit_amt} deposited Sucessfully")
  def withdraw_amt(self,wd_amt):
    if wd_amt < self._bank__balance:
      self._bank__balance -= wd_amt
      print(f"{wd_amt} Withdrawn Sucessfully")

    else:
      print("insufficient Balance")
  def test_meth(self,x):
    return x

canara=savings_acc("Naveen",8755,7411)
canara.deposit_amt(25000)
canara.withdraw_amt(5000)
canara.withdraw_amt(30000)
canara.test_meth("xdcftgyhuiouhgtfr")
# Out:
# 25000 deposited Sucessfully
# 5000 Withdrawn Sucessfully
# insufficient Balance
# 'xdcftgyhuiouhgtfr'

# %% [markdown]
# **7. Discuss the concept of interface classes in Python and their role in achieving abstraction**
#
#
# *   Hiding Implementation Details: Interface classes (implemented through ABCs in Python) hide the internal workings of classes. Users of these classes only need to understand and interact with the methods declared in the interface, not how those methods are implemented in each subclass.
# *   In Python, interface classes are effectively achieved through Abstract Base Classes (ABCs) and the concept of duck typing.

# %%
#@title 8. Create a Python class hierarchy for animals and implement abstraction by defining common methods (e.g., `eat()`, `sleep()`) in an abstract base class
class Animal(ABC):

  def __init__(self,species,classification):
    self.species=species
    self.classification=classification
  @abstractmethod
  def eat():
    pass
  @abstractmethod
  def sleep():
    pass

class Pitbull(Animal):
  def __init__(self,species,classification):
    super().__init__(species,classification)
  def eat(self,food):
    print(f"{self.__class__.__name__} is a {self.classification} , it ate {food}")
  def sleep(self):
    print(f"{self.__class__.__name__} is a {self.species}, it sleeps 4 hours a day ")

class Bird(Animal):
  def __init__(self,species,classification,name):
    super().__init__(species,classification)
    self.name=name
  def eat(self,food):
    print(f"{self.__class__.__name__} is a {self.classification} , it ate {food}")
  def sleep(self):
    print(f"{self.name} the {self.__class__.__name__} is a {self.species} species, it sleeps 10 hours a day ")


Rocky=Pitbull("Canine","Carnivore")
Rocky.eat("BEEF")
Rocky.sleep()

Dove=Bird("Bird","Herbivore","Little Marry")
Dove.eat("Lentils")
Dove.sleep()
# Out:
# Pitbull is a Carnivore , it ate BEEF
# Pitbull is a Canine, it sleeps 4 hours a day
# Bird is a Herbivore , it ate Lentils
# Little Marry the Bird is a Bird species, it sleeps 10 hours a day

# %% [markdown]
# **9. Explain the significance of encapsulation in achieving abstraction. Provide examples.**
#
#
# *   Encapsulation hides the internal state (attributes) of an object, allowing it to expose only the necessary operations (methods). This reduces complexity for the user and promotes abstraction by focusing on what the object can do rather than how it does it.
# *   Treating objects of different classes through a uniform interface, achieved through inheritance and method overriding.

# %% [markdown]
# **10. What is the purpose of abstract methods, and how do they enforce abstraction in Python classes**
#
#
# *    Abstract methods are methods declared in an abstract base class (ABC) but are not implemented in the base class itself. Instead, their implementation is left to be defined by concrete subclasses that inherit from the ABC.
# *   Abstract methods define a contract that subclasses must adhere to. This contract specifies what methods must be implemented by any subclass that inherits from the abstract base class.

# %%
#@title 11. Create a Python class for a vehicle system and demonstrate abstraction by defining common methods (e.g., `start()`, `stop()`) in an abstract base class
class Vehicle(ABC):
  def __init__(self,model,make):
    self.model=model
    self.make=make
  @abstractmethod
  def start():
    pass
  def stop():
    pass
class LMV(Vehicle):
  def __init__(self,model,make,no_of_tyres):
    super().__init__(model,make)
    self.no_of_tyres=no_of_tyres
  def start(self):
    print( f"{self.model} Starts")
  def stop(self):
    print (f"{self.model} Stops")
class HMV(Vehicle):
  def __init__(self,model,make,no_of_tyres):
    super().__init__(model,make)
    self.no_of_tyres=no_of_tyres
  def start(self):
    print( f"{self.model} Starts")
  def stop(self):
    print( f"{self.model} Stops")


Creta=LMV("Creta","Toyota","4")
Creta.start()
Creta.stop()
Bada_Dhosdh=HMV("Bada Dhosdh","Ashok Leyland",8)
Bada_Dhosdh.start()
Bada_Dhosdh.stop()
# Out:
# Creta Starts
# Creta Stops
# Bada Dhosdh Starts
# Bada Dhosdh Stops

# %% [markdown]
# **12. Describe the use of abstract properties in Python and how they can be employed in abstract classes**
#
#
# *   Abstract properties enforce a contract that specifies which attributes (properties) must be implemented by any subclass that inherits from the abstract base class.
# *   An abstract property is declared using the @property decorator along with the @abstractmethod decorator from the abc module.

# %%
#@title . Create a Python class hierarchy for employees in a company (e.g., manager, developer, designer) and implement abstraction by defining a common `get_salary()` method.
#@title 17. Create a Python class hierarchy for employees in a company (e.g., manager, developer, designer) and implement polymorphism through a common `calculate_salary()` method.
class company(ABC):
  def __init__(self,name,age,basic,allowance):
    self.name=name
    self.age=age
    self.basic=basic
    self.allowance=allowance
  @abstractmethod
  def get_salary(self):
    pass
class manager(company):
  def __init__(self,name,age,basic,allowance):
    super().__init__(name,age,basic,allowance)

  def get_salary(self):
    salary= self.basic* (self.allowance/100)
    print(f"the salary of the {self.__class__.__name__} is {salary}")

class designer(company):
  def __init__(self,name,age,basic,allowance):
    super().__init__(name,age,basic,allowance)

  def get_salary(self):
    salary= self.basic* (self.allowance/100)
    print(f"the salary of the {self.__class__.__name__} is {salary}")
class developer(company):
  def __init__(self,name,age,basic,allowance):
    super().__init__(name,age,basic,allowance)

  def get_salary(self):
    salary= self.basic* (self.allowance/100)
    print(f"the salary of the {self.__class__.__name__} is {salary}")
sachin=manager("sachin",55,8000,25)
mankar=designer("Mankar singh",30,80000,50)
karthi=developer("Karthi PK",25,100000,200)
employees=[sachin,karthi,mankar]
for employee in employees:
  employee.get_salary()
# Out:
# the salary of the manager is 2000.0
# the salary of the developer is 200000.0
# the salary of the designer is 40000.0

# %% [markdown]
# **14. Discuss the differences between abstract classes and concrete classes in Python, including their
# instantiation.**
#
# *    Abstract classes may contain abstract methods that must be implemented by subclasses. Concrete classes provide implementations for all inherited methods, including abstract methods.
# *   Abstract classes cannot be instantiated directly; they are designed to be subclassed. Concrete classes, on the other hand, can be instantiated directly to create objects.
#
# *   They may or may not inherit from abstract classes but must provide implementations for all inherited abstract methods if they do.

# %% [markdown]
# **15. Explain the concept of abstract data types (ADTs) and their role in achieving abstraction in Python.**
#
#
# *   Abstract data types (ADTs) play a crucial role in achieving abstraction in Python by providing a structured and standardized way to define and interact with data structures. They promote code reusability, maintainability, and encapsulation of data operations, making complex programming tasks more manageable and less error-prone.
#
#
#
#
# *   ADTs allow programmers to define data structures (such as lists, queues, stacks, trees) and their operations in an abstract manner.

# %%
#@title 16. Create a Python class for a computer system, demonstrating abstraction by defining common methods (e.g., `power_on()`, `shutdown()`) in an abstract base class
from abc import ABC,abstractmethod
class system(ABC):
  @abstractmethod
  def power_on(self):
    pass
  def shut_down(self):
    pass
class windows(system):
  def power_on(self):
    print("This methods Turns On the computer")
  def shut_down(self):
    print("This method Turns off the computer")
Dell=windows()
Dell.power_on()
Dell.shut_down()
# Out:
# This methods Turns On the computer
# This method Turns off the computer

# %% [markdown]
# **Abstraction makes complex software easier to understand by hiding unnecessary details.**
#
#
# *    Abstraction makes complex software easier to understand by hiding unnecessary details.
#
# *   It helps in reusing code, so you don't have to write the same thing over and over again.
# *   It allows you to change how things work inside without affecting how you use them
#
# *   It helps teams work together by providing clear rules for how different parts of the software should interact.

# %% [markdown]
# **18. Explain how abstraction enhances code reusability and modularity in Python programs.**
#
#
# *   By hiding the internal details of how a function or class works, abstraction makes it easier to reuse the same code in different parts of a program without worrying about its implementation.
#
# *   Abstraction encourages modular design by defining clear interfaces (such as classes and functions) that expose only essential functionalities.

# %%
#@title 19. Create a Python class for a library system, implementing abstraction by defining common methods (e.g., `add_book()`, `borrow_book()`) in an abstract base class
from abc import ABC,abstractmethod
class Library(ABC):
  books=[]
  def __init__(self,book_title,author):
    self.book_title=book_title
    self.author=author
  @abstractmethod
  def add_book(self):
    if self.book_title not in self.books:
      self.books.append(self.book_title)
      print(f"The book {self.book_title} added successfully\nAvailable Books in {self.__class__.__name__}:{self.books}")
    else:
      print(f"{self.book_title} is already in the {self.__class__.__name__} section\nAvailable Books in {self.__class__.__name__}:{self.books}")
  @abstractmethod
  def borrow_book(self, book_to_borrow):
        if book_to_borrow in self.books:
            self.books.remove(book_to_borrow)
            print(f"The book '{book_to_borrow}' borrowed successfully.\nAvailable Books in {self.__class__.__name__}: {self.books}")
        else:
            print(f"'{book_to_borrow}' is not available in the {self.__class__.__name__} section.\nAvailable Books in {self.__class__.__name__}: {self.books}")
class Science_Section(Library):
  books=[]
  def __init__(self,book_title,author):
    super().__init__(book_title,author)
  def add_book(self):
    super().add_book()
  def borrow_book(self,book_to_borrow):
    super().borrow_book(book_to_borrow)
class Literature_Section(Library):
  def __init__(self,book_title,author):
    super().__init__(book_title,author)
  def add_book(self):
    super().add_book()
  def borrow_book(self,book_to_borrow):
    super().borrow_book(book_to_borrow)


book1=Science_Section('FOCP',"Ankit Bansal")
book2=Literature_Section("Art of War","Sun Tzu")
book3=Science_Section('FOCP-II',"Ankit Bansal")
book4=Literature_Section("All about love","William Shakeshere")
books=[book1,book3,book2,book4]
for book in books:
  book.add_book()
print("------------------------------------")
book3.borrow_book("FOCP-II")
# Out:
# The book FOCP added successfully
# Available Books in Science_Section:['FOCP']
# The book FOCP-II added successfully
# Available Books in Science_Section:['FOCP', 'FOCP-II']
# The book Art of War added successfully
# Available Books in Literature_Section:['Art of War']
# The book All about love added successfully
# Available Books in Literature_Section:['Art of War', 'All about love']
# ------------------------------------
# The book 'FOCP-II' borrowed successfully.
# Available Books in Science_Section: ['FOCP']

# %% [markdown]
# **20. Describe the concept of method abstraction in Python and how it relates to polymorphism.**
#
#
# *   Method abstraction involves defining methods in a class without specifying their implementation details.
# *   This is often achieved using abstract methods in abstract base classes (ABCs) or by defining methods in a way that focuses on what the method does rather than how it does it.

# %% [markdown]
# **Composition:**

# %% [markdown]
# **1. Explain the concept of composition in Python and how it is used to build complex objects from simpler ones**
#
#
# *   *Composition* refers to the principle of creating  complex objects by combining simple objects or classes.
# *   Composite class can be called into component class,by calling a class name that need to be used.

# %% [markdown]
# **2. Describe the difference between composition and inheritance in object-oriented programming.**
#
#
#
#
# *   *Composition* establishes a *Has-a* relationship between the Composite class and the component class.Also The methods of the composite class cannot be overriden,but can be implemented inside Component class.
# *   *Inheritance* establishes a *is-a* relationship between the Base class and the sub class.Also The methods of the base class can be overriden and implemented inside sub class.

# %%
#@title 3. Create a Python class called `Author` with attributes for name and birthdate. Then, create a `Book` class that contains an instance of `Author` as a composition. Provide an example of creating a `Book` object.
class Author:
  def __init__(self,name,dob):
    self.name=name
    self.dob=dob
  def Author_details(self):
    print(self.name,self.dob)


class Book:
  def __init__(self,name,dob):
    self.name=name
    self.dob=dob
    self.obj=Author(self.name,self.dob)
  def obj_details(self):
    self.obj.Author_details()

DoItToday=Book("James Allen",1700)
DoItToday.obj_details()
# Out:
# James Allen 1700

# %% [markdown]
# **4. Discuss the benefits of using composition over inheritance in Python, especially in terms of code flexibility
# and reusability.**
#
#
# *   Composition allows objects to change behavior at runtime by swapping components, whereas inheritance binds classes at compile-time.
# *   Objects can be composed of different components, reducing tight coupling compared to the rigid hierarchy of inheritance.

# %% [markdown]
# ****
#
#
#
# *   List item
# *   List item

# %%
#@title 5. How can you implement composition in Python classes? Provide examples of using composition to create complex objects.
#@markdown  Composition can be implemented by creating classes that contain instances of other classes as attributes. This allows you to build complex objects by combining simpler components.

class engine:
  def start(self):
    print("Engine starting")
  def stop(self):
    print("Engine stopping")

class car:
  def __init__(self):
    self.obj=engine()
  def start(self):
    print("Car Starting")
    self.obj.start()
  def stop(self):
    print("Car stopping")
    self.obj.stop()

Altroz=car()
Altroz.start()
Altroz.stop()
# Out:
# Car Starting
# Engine starting
# Car stopping
# Engine stopping

# %%
#@title 6. Create a Python class hierarchy for a music player system, using composition to represent playlists and songs.
class Song:
  def __init__(self,title,artist,duration):
    self.title=title
    self.artist=artist
    self.duration=duration
  def play(self):
    print(f"{self.title} by {self.artist} is being played")

class Playlist:
  def __init__(self,name):
    self.name=name
    self.songs=[]
  def add_song(self,song):
    if isinstance(song,Song):
      self.songs.append(song)
    else:
      raise TypeError("Expected an Instance")
  def remove_song(self,song):
    self.songs.remove(song)
  def play_playlist(self):
    print(f"{self.name} Playlist is playing: ")
    for song in self.songs:
      song.play()
class MusicPlayer:
  def __init__(self):
    self.playlists={}
  def add_playlist(self,name):
    if name not in self.playlists:
      self.playlists[name]=Playlist(name)
    else:
      print("Playlist already exists")
  def del_playlist(self,name):
    if name in self.playlists:
      del self.playlists[name]
    else:
      print("Playlist does not exists")
  def add_song_2_playlist(self,playlist_name,song):
    if playlist_name in self.playlists:
      self.playlists[playlist_name].add_song(song)
    else:
      print(f"{playlist_name} Does not exists")
  def del_song_from_playlist(self,playlist_name,song):
    if playlist_name in self.playlists:
      self.playlists[playlist_name].remove_song(song)
    else:
      print(f"{playlist_name} Does not exists")
  def play_playlist(self,playlist_name):
    if playlist_name in self.playlists:
      self.playlists[playlist_name].play_playlist()
    else:
      print(f"{playlist_name} Does not exists")

song1=Song("Shape of you","Edsheeran",240)
song2=Song("Raise of Raguvaran","Anirudh",120)
song3=Song("Despasito","Louis",150)

Spotify=MusicPlayer()
Spotify.add_playlist('party')
Spotify.add_playlist("Romance")
Spotify.add_song_2_playlist("party",song1)
Spotify.add_song_2_playlist("party",song2)
Spotify.add_song_2_playlist("Romance",song3)
Spotify.play_playlist("Romance")
# Out:
# Romance Playlist is playing:
# Despasito by Louis is being played

# %% [markdown]
# **7. Explain the concept of "has-a" relationships in composition and how it helps design software systems.**
#
#
# *   The concept of "has-a" relationships in object-oriented programming refers to the notion that one class (or object) contains, or is composed of, another class (or object) as a part of its own structure. This relationship is typically implemented using composition, where one class holds a reference to another class as a member field.
# *   Composition supports modularity by breaking down complex systems into smaller, more manageable parts. Each class can focus on a specific aspect of functionality, making the codebase easier to understand, maintain, and extend.

# %%
#@title 8. Create a Python class for a computer system, using composition to represent components like CPU, RAM, and storage devices.

class CPU:
  def __init__(self,brand,model,core):
    self.brand=brand
    self.core=core
    self.model=model
  def __str__(self):
    return (f"CPU:{self.brand}{self.model},Cores:{self.core}")
class RAM:
  def __init__(self,storage,speed_mhz):
    self.storage=storage
    self.speed_mhz=speed_mhz
  def __str__(self):
    return (f"RAM:{self.storage}GB,SPEED:{self.speed_mhz}")
class Storage:
  def __init__(self,capacity,type):
    self.capacity=capacity
    self.type=type
  def __str__(self):
    return f"Storage {self.capacity},Type:{self.type}"
class Computer:
  def __init__(self,cpu,ram,storage):
    self.cpu=cpu
    self.ram=ram
    self.storage=storage
  def computer_properties(self):
    print( self.cpu)
    print( self.ram)
    print(self.storage)

cpu = CPU("Intel", "i7-10700K", 8)
ram = RAM(16, 3200)
storage = Storage(512, "SSD")

my_computer = Computer(cpu, ram, storage)
my_computer.computer_properties()
# Out:
# CPU:Inteli7-10700K,Cores:8
# RAM:16GB,SPEED:3200
# Storage 512,Type:SSD

# %% [markdown]
# **9. Describe the concept of "delegation" in composition and how it simplifies the design of complex systems.**
#
#
# *   The concept of "delegation" in composition refers to the practice where an object forwards a task or responsibility to another object, typically one of its components, instead of handling it internally
# *   Delegation promotes encapsulation by allowing each object to focus on a specific responsibility. The client object does not need to implement all behaviors itself but rather delegates appropriate responsibilities to its components.

# %%
#@title 10. Create a Python class for a car, using composition to represent components like the engine, wheels, and transmission
class engine:
  def start(self):
    print("Engine starting")
  def stop(self):
    print("Engine stopping")
class wheels:
  def wheel_check(self):
    print("Wheels ready to roll")
class Transmission:
  def status_transmission(self):
    print("Oil Condition ok")

class car:
  def __init__(self):
    self.obj=engine()
    self.wheelstatus=wheels()
    self.transmission_status=Transmission()
  def start(self):
    print("Car Starting")
    self.obj.start()
    self.wheelstatus.wheel_check()
    self.transmission_status.status_transmission()
  def stop(self):
    print("Car stopping")
    self.obj.stop()

Altroz=car()
Altroz.start()
Altroz.stop()
# Out:
# Car Starting
# Engine starting
# Wheels ready to roll
# Oil Condition ok
# Car stopping
# Engine stopping

# %% [markdown]
# **11. How can you encapsulate and hide the details of composed objects in Python classes to maintain
# abstraction**
#
#
# *   Encapsulation and hiding the details of composed objects within classes can be achieved primarily through the use of private variables and methods.

# %%
#@title 12. Create a Python class for a university course, using composition to represent students, instructors, and course materials.
class University:
  def __init__(self,course_name):
    self.course_name=course_name
  def course_details(self):
    print(f"This method returns course name {self.course_name}")
  def course_materials(self):
    print(f"The course materials of the course {self.course_name} is provided in this method")
class students:
  def __init__(self,name,course_enrolled):
    self.name=name
    self.course_enrolled=University(course_enrolled)
  def student_details(self):
    print(f"The student {self.name} is studying {self.course_enrolled.course_name}")

  def study_material(self):
    course_enrolled.course_materials()

class Instructors:
  def __init__(self,name,course_handled):
    self.name=name
    self.course_handled=University(course_handled)
  def Instructor_details(self):
    print(f"The Instructor {self.name} is Handling {self.course_handled.course_name}")

  def study_material(self):
    course_handled.course_materials()

ds=University("datascience")
kavin=students("Kavin","datascience")
sudh=Instructors("Sudhanshu kumar","Datascience")
kavin.student_details()
# Out:
# The student Kavin is studying datascience

# %% [markdown]
# **13. Discuss the challenges and drawbacks of composition, such as increased complexity and potential for tight coupling between objects.**
#
# *   Designing a system using composition requires careful consideration of object relationships, responsibilities, and interactions. Poorly designed compositions can lead to bloated, hard-to-maintain codebases.
# *   Defining clear and consistent interfaces between composed objects is crucial for ensuring that they work together seamlessly. Inadequate interface design can lead to misunderstandings and compatibility issues.

# %%
#@title 14. Create a Python class hierarchy for a restaurant system, using composition to represent menus, dishes, and ingredients.
class Ingredient:
  def __init__(self,name,qty,unit,ppu):
    self.name=name
    self.qty=qty
    self.ppu=ppu
    self.unit=unit

class Dish:
  def __init__(self,name,description,ingredients):
    self.name=name
    self.description=description
    self.ingredients=ingredients

class Menu:
  def __init__(self,type,description,dishes):
    self.type=type
    self.description=description
    self.dishes=dishes
class Restaurant:
  def __init__(self,name,location,menus):
    self.name=name
    self.location=location
    self.menus=menus

Ingredient1=Ingredient("Tomato",250,"kg",35)
Ingredient2=Ingredient("Potato",300,"kg",50)

Dish1=Dish("tomato soup",description="something fishy",ingredients=[Ingredient1])
Dish2=Dish("Potato Fry",description="something Fry",ingredients=[Ingredient2])

Lunch=Menu("Lunch Menu","buecbuewbyuc",[Dish1,Dish2])
Kongu_rest=Restaurant("New Kongu Restaurant",'Press colony',[Lunch])

for menu in Kongu_rest.menus:
  print(menu.type)
  for dish in Lunch.dishes:
    print(dish.name)
    for ingredient in dish.ingredients:
      print(f"Ingredient:{ingredient.name}")
# Out:
# Lunch Menu
# tomato soup
# Ingredient:Tomato
# Potato Fry
# Ingredient:Potato

# %% [markdown]
# **15. Explain how composition enhances code maintainability and modularity in Python programs.**
#
# *   Composition allows you to encapsulate functionality into smaller, manageable classes. Each class is responsible for a specific task or role, which promotes the Single Responsibility Principle (SRP).
# *   By composing objects rather than inheriting from them (as in inheritance), you can reuse functionality across different parts of your application. This promotes code reuse and reduces duplication, as you can use the same components in various contexts without modifying their internal implementation

# %%
#@title 16. Create a Python class for a computer game character, using composition to represent attributes like weapons, armor, and inventory.

class Weapons:
  def __init__(self,weapon_type,weapon_name):

    self.weapon_type=weapon_type
    self.weapon_name=weapon_name

class Armors:
  def __init__(self,armor_name,armor_type):
    self.armor_name=armor_name
    self.armor_type=armor_type

class inventory:
  def __init__(self,weapons,armors):
    self.weapons=weapons
    self.armors=armors
class Character:
  def __init__(self,name,power,inventory):
    self.name=name
    self.power=power
    self.inventory=inventory

class Game:
  def __init__(self,name,character):
    self.name=name
    self.character=character
Ak47=Weapons("Gun","AK47")
ArgesHG84=Weapons("Bomb","ArgesHG84")
bp=Armors("Vest","220mm Buletproof vest")
border_CS=inventory([Ak47,ArgesHG84],[bp])
Bond=Character("JamesBond","Counter strike,Spy",border_CS)
Arena=Game("Freefire",Bond)
print(f"The game {Arena.name} Starts")
print(f"Select the below character\n{Arena.character.name}")
print(f"Power of {Arena.character.name} is {Arena.character.power}")
for weapon in Bond.inventory.weapons:
  print(weapon.weapon_name)
# Out:
# The game Freefire Starts
# Select the below character
# JamesBond
# Power of JamesBond is Counter strike,Spy
# AK47
# ArgesHG84

# %% [markdown]
# **17. Describe the concept of "aggregation" in composition and how it differs from simple composition**
#
# *   Aggregation implies a weaker relationship and loose coupling, where objects can exist independently, and the whole object has a reference to its part objects.
# *   Composition implies strong ownership and tight coupling between objects, where the whole object manages the lifecycle of its part objects.

# %%
#@title 18. Create a Python class for a house, using composition to represent rooms, furniture, and appliances.
class furniture:
  def __init__(self,name):
    self.name=name
class appliance:
  def __init__(self,name):
    self.name=name
class room:
  def __init__(self,name):
    self.name=name
    self.furnitures=[]
    self.appliances=[]

  def add_furniture(self,furniture):
    self.furnitures.append(furniture)
  def add_appliance(self,appliance):
    self.appliances.append(appliance)

class house:
  def __init__(self,bhk,address,room):
    self.bhk=bhk
    self.address=address
    self.room=room
    self.rooms=[]
  def add_rooms(self,room):
    self.rooms.append(room)

sofa=furniture("sofa")
bed=furniture("bed")
dressing_table=furniture("Dressing_table")
lamp=appliance("Night_lamp")
hall=room("Hall")
hall.add_appliance(sofa)
bedroom=room("bedroom")
bedroom.add_appliance(lamp)
Sweet_home=house(3,"20/1,prescolony,pyvillage",[hall,bedroom])
Sweet_home.add_rooms(hall)
Sweet_home.add_rooms(bedroom)
for room in Sweet_home.room:
  print("Room:",room.name)
  for furniture in room.appliances:
    print("Furniture:", furniture.name)
# Out:
# Room: Hall
# Furniture: sofa
# Room: bedroom
# Furniture: Night_lamp

# %% [markdown]
# **19. How can you achieve flexibility in composed objects by allowing them to be replaced or modified
# dynamically at runtime**
#
# *   Dependency Injection is a design pattern where objects receive dependencies from an external source rather than creating them internally.
# *   The Strategy Pattern defines a family of algorithms, encapsulates each one, and makes them interchangeable

# %%
#@title 20. Create a Python class for a social media application, using composition to represent users, posts, and comments
class User:
    def __init__(self, username):
        self.username = username
        self.posts = []
        self.comments = []

    def create_post(self, content):
        post = Post(content, self)
        self.posts.append(post)
        return post

    def add_comment(self, post, content):
        comment = Comment(content, self, post)
        self.comments.append(comment)
        post.add_comment(comment)
        return comment

class Post:
    def __init__(self, content, author):
        self.content = content
        self.author = author
        self.comments = []

    def add_comment(self, comment):
        self.comments.append(comment)

class Comment:
    def __init__(self, content, author, post):
        self.content = content
        self.author = author
        self.post = post


user1 = User("Alice")
user2 = User("Bob")


post1 = user1.create_post("Hello, this is my first post!")


comment1 = user2.add_comment(post1, "Nice post, Alice!")


print(f"User: {user1.username}")
print(f"  Post: {post1.content}")
print(f"    Comments:")
for comment in post1.comments:
    print(f"      - {comment.author.username}: {comment.content}")

print(f"\nUser: {user2.username}")
print(f"  Comment: {comment1.content}")
print(f"    Post: {comment1.post.content}")
print(f"    Author of post: {comment1.post.author.username}")
# Out:
# User: Alice
#   Post: Hello, this is my first post!
#     Comments:
#       - Bob: Nice post, Alice!
#
# User: Bob
#   Comment: Nice post, Alice!
#     Post: Hello, this is my first post!
#     Author of post: Alice
